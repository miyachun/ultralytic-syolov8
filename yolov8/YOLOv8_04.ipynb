# %%
# Git clone and run tests on updates branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
# !pip install colab-cli

# %%
# !yolo track model=yolov8n-pose.pt source="people.mp4"
# Out:
# Ultralytics YOLOv8.2.67 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-pose summary (fused): 187 layers, 3,289,964 parameters, 0 gradients, 9.2 GFLOPs
#
# video 1/1 (frame 1/692) /content/people.mp4: 384x640 1 person, 113.0ms
# video 1/1 (frame 2/692) /content/people.mp4: 384x640 1 person, 16.8ms
# video 1/1 (frame 3/692) /content/people.mp4: 384x640 1 person, 7.5ms
# video 1/1 (frame 4/692) /content/people.mp4: 384x640 1 person, 8.8ms
# video 1/1 (frame 5/692) /content/people.mp4: 384x640 1 person, 7.3ms
# video 1/1 (frame 6/692) /content/people.mp4: 384x640 1 person, 7.0ms
# video 1/1 (frame 7/692) /content/people.mp4: 384x640 1 person, 7.0ms
# video 1/1 (frame 8/692) /content/people.mp4: 384x640 1 person, 7.2ms
# video 1/1 (frame 9/692) /content/people.mp4: 384x640 1 person, 7.1ms
# video 1/1 (frame 10/692) /content/people.mp4: 384x640 1 person, 7.8ms
# video 1/1 (frame 11/692) /content/people.mp4: 384x640 1 person, 7.6ms
# ...

# %%
# !ffmpeg -i /content/ultralytics/runs/pose/track2/people.avi output.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
from google.colab import files
files.download('/content/ultralytics/runs/pose/track2/people.avi')
