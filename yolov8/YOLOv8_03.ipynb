# %%
# Git clone and run tests on updates branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 31569, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 31569 (delta 158), reused 198 (delta 142), pack-reused 31329
# Receiving objects: 100% (31569/31569), 15.69 MiB | 12.27 MiB/s, done.
# Resolving deltas: 100% (22850/22850), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 20.7 MB/s eta 0:00:00
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
import zipfile
from google.colab import drive

drive.mount('/content/drive/')
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/smeshariks_ultralytics.zip", 'r')
# !unzip "/content/drive/MyDrive/smeshariks_ultralytics.zip"
# Out:
# Mounted at /content/drive/
# Archive:  /content/drive/MyDrive/smeshariks_ultralytics.zip
#   inflating: smeshariks_ultralytics/smeshariks.yaml
#    creating: smeshariks_ultralytics/smeshariks/
#    creating: smeshariks_ultralytics/smeshariks/images/
#    creating: smeshariks_ultralytics/smeshariks/images/test/
#   inflating: smeshariks_ultralytics/smeshariks/images/test/1_jpg.rf.0b06399476f1932a656993139e3eb8e6.jpg
#   inflating: smeshariks_ultralytics/smeshariks/images/test/17_jpg.rf.184db250eeac8655ee891d9c88e8f9e1.jpg
#   inflating: smeshariks_ultralytics/smeshariks/images/test/23_jpg.rf.0b8f70b060e82a7c83313a9fd5005040.jpg
#   inflating: smeshariks_ultralytics/smeshariks/images/test/327473_jpg.rf.1f2e55d3e6ab8fd6237a87922bb59b8b.jpg
#   inflating: smeshariks_ultralytics/smeshariks/images/test/hq720_jpg.rf.48525cf7f6cca0a50d5041c0b9c4bff8.jpg
#   inflating: smeshariks_ultralytics/smeshariks/images/test/hx3wwJy_png.rf.958b6b7a59d5dc5bbb7e2e705dfc7432.jpg
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/smeshariks_ultralytics/smeshariks.yaml epochs=500 imgsz=640
# Out:
# Ultralytics YOLOv8.2.67 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model=ultralytics/runs/detect/train3/weights/last.pt source='smeshariks_ultralytics/smeshariks/images/test/i-8_jpeg.rf.d04023875b80d94b34a381711ac1e3f7.jpg'
# Out:
# Ultralytics YOLOv8.2.67 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,007,403 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/smeshariks_ultralytics/smeshariks/images/test/i-8_jpeg.rf.d04023875b80d94b34a381711ac1e3f7.jpg: 640x640 2 barashs, 1 ezh, 2 kroshs, 1 nusha, 10.8ms
# Speed: 3.3ms preprocess, 10.8ms inference, 580.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/ultralytics/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('/content/ultralytics/runs/detect/predict4/i-8_jpeg.rf.d04023875b80d94b34a381711ac1e3f7.jpg') #Replace "image.jpg" with the path of your image
plt.imshow(img)
plt.axis('off')
plt.show()
